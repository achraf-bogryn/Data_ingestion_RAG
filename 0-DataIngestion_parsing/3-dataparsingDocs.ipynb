# %% [markdown]
# ### Word Document Processing

# %%
from langchain_community.document_loaders import Docx2txtLoader,UnstructuredWordDocumentLoader

# %%
## MEthod1: Using Docx2txtLoader
print("1️⃣ Using Docx2txtLoader")
try:
    docx_loader=Docx2txtLoader("data/word_files/v1.docx")
    docs=docx_loader.load()
    print(f"✅ Loaded {len(docs)} document(s)")
    print(f"Content preview: {docs[0].page_content[:200]}...")
    print(f"Metadata: {docs[0].metadata}")

except Exception as e:
    print(f"Error: {e}")
# Out:
# 1️⃣ Using Docx2txtLoader
# ✅ Loaded 1 document(s)
# Content preview: PAGE 10
#
# ISSN: 0000-0000
#
# ❒
#
#
#
# Journal Shortname
#
# ISSN: 0000-0000
#
#  PAGE 11
#
# ❒
#
# Data Science and Innovation: Artificial Intelligence and Application
#
# Vol. 99, No. 1, July 2024, pp. 1 1x
#
# ∼
#
# 		ISSN: 00...
# Metadata: {'source': 'data/word_files/v1.docx'}

# %%
## MEthod2
print("\n2️⃣ Using UnstructuredWordDocumentLoader")

try:
    unstructured_loader=UnstructuredWordDocumentLoader("data/word_files/v1.docx",mode="elements")
    unstructured_docs=unstructured_loader.load()
    
    print(f"✅ Loaded {len(unstructured_docs)} elements")
    for i, doc in enumerate(unstructured_docs[:3]):
        print(f"\nElement {i+1}:")
        print(f"Type: {doc.metadata.get('category', 'unknown')}")
        print(f"Content: {doc.page_content[:100]}...")


except Exception as e:
    print(e)
# Out:
# 2️⃣ Using UnstructuredWordDocumentLoader
# ✅ Loaded 134 elements
#
# Element 1:
# Type: Title
# Content: Data Science and Innovation: Artificial Intelligence and Application...
#
# Element 2:
# Type: UncategorizedText
# Content: Vol. 99, No. 1, July 2024, pp. 1 1x...
#
# Element 3:
# Type: UncategorizedText
# Content: ISSN: 0000-0000, DOI: 10./.v99.i1.pp1-1x	❒	1...

# %%
unstructured_docs[0]
# Out:
# Document(metadata={'source': 'data/word_files/v1.docx', 'category_depth': 0, 'file_directory': 'data/word_files', 'filename': 'v1.docx', 'last_modified': '2026-02-09T15:41:47', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': '06c0cc0b184817e26ac97441a379a62d'}, page_content='Data Science and Innovation: Artificial Intelligence and Application')
