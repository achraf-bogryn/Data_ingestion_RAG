# %% [markdown]
# ### ASTRADB VectorStore
# Go from app idea to production with the AI Platform with Astra DB, the ultra-low latency database made for AI and Langflow, the low-code RAG IDE
# https://www.datastax.com/

# %%
# !pip install \
    "langchain>=0.3.23,<0.4" \
    "langchain-core>=0.3.52,<0.4" \
    "langchain-astradb>=0.6,<0.7"
# Out:
# Requirement already satisfied: langchain<0.4,>=0.3.23 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<0.4,>=0.3.52 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (0.3.83)
# Collecting langchain-astradb<0.7,>=0.6
#   Downloading langchain_astradb-0.6.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (2.12.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (2.0.46)
# Requirement already satisfied: requests<3,>=2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (6.0.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain<0.4,>=0.3.23) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<0.4,>=0.3.52) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<0.4,>=0.3.52) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<0.4,>=0.3.52) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<0.4,>=0.3.52) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<0.4,>=0.3.52) (0.14.0)
# Collecting astrapy<3.0.0,>=2.0.1 (from langchain-astradb<0.7,>=0.6)
#   Downloading astrapy-2.1.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.21 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-astradb<0.7,>=0.6) (2.0.2)
# Collecting deprecation~=2.1.0 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: h11>=0.16.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.25.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.28.1)
# Collecting pymongo>=3 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading pymongo-4.16.0-cp39-cp39-win_amd64.whl.metadata (10.0 kB)
# Requirement already satisfied: toml<1.0.0,>=0.10.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.10.2)
# Collecting uuid6>=2024.1.12 (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.12.1)
# Requirement already satisfied: certifi in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (1.0.9)
# Requirement already satisfied: idna in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (3.11)
# Collecting h2<5,>=3 (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4,>=0.3.52) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith>=0.1.17->langchain<0.4,>=0.3.23) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith>=0.1.17->langchain<0.4,>=0.3.23) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith>=0.1.17->langchain<0.4,>=0.3.23) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3.23) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from requests<3,>=2->langchain<0.4,>=0.3.23) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4,>=0.3.23) (3.2.4)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo>=3->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from anyio->httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (1.3.0)
# Downloading langchain_astradb-0.6.1-py3-none-any.whl (58 kB)
# Downloading astrapy-2.1.0-py3-none-any.whl (333 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading pymongo-4.16.0-cp39-cp39-win_amd64.whl (753 kB)
#    ---------------------------------------- 0.0/753.8 kB ? eta -:--:--
#    ---------------------------------------- 753.8/753.8 kB 7.9 MB/s  0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Installing collected packages: uuid6, hyperframe, hpack, dnspython, deprecation, pymongo, h2, astrapy, langchain-astradb
#
#    ---- ----------------------------------- 1/9 [hyperframe]
#    -------- ------------------------------- 2/9 [hpack]
#    -------- ------------------------------- 2/9 [hpack]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ------------- -------------------------- 3/9 [dnspython]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    ---------------------- ----------------- 5/9 [pymongo]
#    -------------------------- ------------- 6/9 [h2]
#    -------------------------- ------------- 6/9 [h2]
#    -------------------------- ------------- 6/9 [h2]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ------------------------------- -------- 7/9 [astrapy]
#    ----------------------------------- ---- 8/9 [langchain-astradb]
#    ----------------------------------- ---- 8/9 [langchain-astradb]
#    ---------------------------------------- 9/9 [langchain-astradb]
#
# Successfully installed astrapy-2.1.0 deprecation-2.1.0 dnspython-2.7.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 langchain-astradb-0.6.1 pymongo-4.16.0 uuid6-2025.0.1

# %%
# !pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (0.3.35)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain_openai) (0.3.83)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain_openai) (2.17.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (2.12.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain_openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (4.12.1)
# Requirement already satisfied: certifi in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain_openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain_openai) (4.67.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain_openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain_openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.1.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_openai) (2.6.3)
# Requirement already satisfied: colorama in c:\users\achra\appdata\local\anaconda3\envs\rag_project\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain_openai) (0.4.6)
