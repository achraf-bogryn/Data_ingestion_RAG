# %% [markdown]
# ## QMS_Data_Ingestion

# %%
import os
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.runnables import RunnableSequence
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Document Loading

# %%
from langchain_community.document_loaders import DirectoryLoader,TextLoader

# Load documents from directory
dir_loader=DirectoryLoader(
    "../data",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=True

)
documents = dir_loader.load()

print(f"Loaded {len(documents)} documents")
print(f"\nFirst document preview:")
print(documents[0].page_content[:200] + "...")
# Out:
# 100%|██████████| 11/11 [00:00<00:00, 3679.21it/s]
# Loaded 11 documents
#
# First document preview:
# ISO 13485:2016
# Clause: 4.1.1
# Title: General Quality Management System Requirements
#
# SUMMARY:
# Clause 4.1.1 requires the organization to establish, document, implement, and maintain a Quality Management...

# %%
documents
# Out:
# [Document(metadata={'source': '..\\data\\iso_13485\\4.1.1_general_qms_requirement.txt'}, page_content='ISO 13485:2016\nClause: 4.1.1\nTitle: General Quality Management System Requirements\n\nSUMMARY:\nClause 4.1.1 requires the organization to establish, document, implement, and maintain a Quality Management System (QMS). The organization must define the QMS scope and clearly identify its regulatory role.\n\nREQUIREMENTS:\n- Define the scope and perimeter of the QMS\n- Identify and document the regulatory role of the organization (manufacturer, importer, distributor, etc.)\n- Establish and maintain a documented QMS compliant with ISO 13485 and applicable regulatory requirements\n\nMANDATORY PROCESS:\nProcess Name: QMS Governance and Scope Definition\nProcess Description:\nThis process ensures that the organization formally defines its QMS scope, regulatory responsibilities, and establishes a documented system aligned with ISO 13485 requirements.\n\nREQUIRED DOCUMENTS:\n- Quality Manual\n- Documented QMS scope description\n- Defined regulatory roles documentation\n- Quality Policy\n\nREQUIRED RECORDS:\n- Evidence of QMS implementation\n- Governance approval records\n\nEXPECTED EVIDENCE:\n- Approved Quality Manual\n- Defined organizational regulatory role\n- Implementation proof of QMS processes\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.2_process_approach_risk_based.txt'}, page_content='ISO 13485:2016\nClause: 4.1.2\nTitle: Process Approach and Risk-Based Approach\n\nSUMMARY:\nClause 4.1.2 requires the organization to apply a process-based approach within the QMS and integrate risk-based thinking into process control and management.\n\nREQUIREMENTS:\n- Identify all processes necessary for the QMS\n- Define the sequence and interaction between processes\n- Apply a risk-based approach to process control\n- Ensure risk management is integrated into process planning and execution\n\nMANDATORY PROCESS:\nProcess Name: Process Management and Risk Integration\nProcess Description:\nThis process ensures systematic identification, mapping, and risk evaluation of QMS processes, integrating risk-based thinking into process control and monitoring.\n\nREQUIRED DOCUMENTS:\n- Process mapping documentation\n- Process interaction diagram\n- Risk-based approach procedure\n\nREQUIRED RECORDS:\n- Process risk analyses\n- Process review records\n\nEXPECTED EVIDENCE:\n- Approved process map\n- Documented risk assessments per process\n- Evidence of risk-based decision making\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.3_process_monitoring_control.txt'}, page_content='ISO 13485:2016\nClause: 4.1.3\nTitle: Monitoring and Control of Processes\n\nSUMMARY:\nClause 4.1.3 requires the organization to define criteria and methods to ensure effective operation and control of QMS processes, including monitoring, measurement, and record retention.\n\nREQUIREMENTS:\n- Define operational criteria and control methods for processes\n- Establish performance indicators (KPIs) where appropriate\n- Monitor and measure processes\n- Maintain records demonstrating process control\n\nMANDATORY PROCESS:\nProcess Name: Process Monitoring and Performance Control\nProcess Description:\nThis process ensures the organization defines measurable criteria, monitors performance indicators, and maintains records demonstrating effective process control.\n\nREQUIRED DOCUMENTS:\n- Process procedures\n- Defined KPI framework\n- Monitoring and measurement procedures\n\nREQUIRED RECORDS:\n- Monitoring reports\n- KPI results\n- Process performance records\n\nEXPECTED EVIDENCE:\n- Documented monitoring results\n- KPI tracking logs\n- Records demonstrating process stability and control\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.4_qms_change_management.txt'}, page_content='ISO 13485:2016\nClause: 4.1.4\nTitle: Control of Changes to the QMS and Product\n\nSUMMARY:\nClause 4.1.4 requires the organization to control changes affecting the Quality Management System (QMS) or medical device conformity. All changes must be identified, evaluated, approved, and implemented in a controlled manner.\n\nREQUIREMENTS:\n- Identify proposed changes affecting the QMS\n- Evaluate the impact of changes on the QMS and on the medical device/product\n- Approve changes prior to implementation\n- Ensure controlled implementation of approved changes\n\nMANDATORY PROCESS:\nProcess Name: QMS Change Management and Control\nProcess Description:\nThis process ensures that any change affecting the QMS or product conformity is formally assessed, approved, documented, and implemented under controlled conditions.\n\nREQUIRED DOCUMENTS:\n- Change management procedure\n\nREQUIRED RECORDS:\n- Change register\n- Approved impact assessment records\n- Change approval documentation\n\nEXPECTED EVIDENCE:\n- Documented impact analyses\n- Approved change requests\n- Traceability of implemented changes\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.5_outsourced_process_control.txt'}, page_content='ISO 13485:2016\nClause: 4.1.5\nTitle: Control of Outsourced Processes\n\nSUMMARY:\nClause 4.1.5 requires the organization to control outsourced processes that impact product conformity. Monitoring and control mechanisms must be proportionate to the associated risk.\n\nREQUIREMENTS:\n- Identify outsourced processes impacting product conformity\n- Define monitoring and control measures proportionate to risk\n- Formalize quality requirements in written agreements with external providers\n\nMANDATORY PROCESS:\nProcess Name: Outsourced Process Control\nProcess Description:\nThis process ensures that externally provided processes are evaluated, monitored, and controlled to maintain product conformity and regulatory compliance.\n\nREQUIRED DOCUMENTS:\n- Outsourcing control procedure\n- Supplier quality agreements\n- Contractual quality requirements\n\nREQUIRED RECORDS:\n- Supplier evaluations\n- Supplier audit reports\n- Monitoring and performance records\n\nEXPECTED EVIDENCE:\n- Approved supplier agreements\n- Documented supplier evaluations\n- Audit findings and follow-up actions\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.6_qms_software_validation.txt'}, page_content='ISO 13485:2016\nClause: 4.1.6\nTitle: Validation of Software Used in the QMS\n\nSUMMARY:\nClause 4.1.6 requires the organization to validate software used within the QMS prior to initial use and after modifications when necessary. Risks associated with software use must be assessed.\n\nREQUIREMENTS:\n- Identify all software used in QMS processes\n- Assess risks associated with software usage\n- Validate software before initial use\n- Revalidate software after changes when required\n\nMANDATORY PROCESS:\nProcess Name: QMS Software Validation\nProcess Description:\nThis process ensures that software tools used in QMS activities are risk-assessed, validated, and maintained in a validated state to ensure reliability and compliance.\n\nREQUIRED DOCUMENTS:\n- Software validation procedure\n- QMS software register\n\nREQUIRED RECORDS:\n- Software validation reports\n- Revalidation records\n- Validation logs\n\nEXPECTED EVIDENCE:\n- Documented validation protocols\n- Approved validation results\n- Risk assessment documentation for software tools\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.1_qms_documentation_requirements.txt'}, page_content='ISO 13485:2016\nClause: 4.2.1\nTitle: General Documentation Requirements\n\nSUMMARY:\nClause 4.2.1 requires the organization to establish and maintain documented information required by ISO 13485. The documentation architecture of the QMS must be structured and controlled.\n\nREQUIREMENTS:\n- Identify all documents and records required by ISO 13485\n- Structure the QMS documentation architecture\n- Maintain a master list of controlled documents\n- Ensure documents remain current and accessible\n\nMANDATORY PROCESS:\nProcess Name: QMS Documentation Architecture Management\nProcess Description:\nThis process ensures identification, structuring, control, and maintenance of all QMS documentation in accordance with ISO 13485 requirements.\n\nREQUIRED DOCUMENTS:\n- Documentation architecture description\n- Master list of controlled documents\n- Document control procedure\n\nREQUIRED RECORDS:\n- Document history records\n- Evidence of document control activities\n\nEXPECTED EVIDENCE:\n- Approved documentation structure\n- Updated master document list\n- Controlled access and version management records\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.2_quality_manual.txt'}, page_content='ISO 13485:2016\nClause: 4.2.2\nTitle: Quality Manual\n\nSUMMARY:\nClause 4.2.2 requires the organization to establish and maintain a Quality Manual defining the scope of the QMS and describing process interactions.\n\nREQUIREMENTS:\n- Establish a documented Quality Manual\n- Define the QMS scope within the manual\n- Justify exclusions or non-applicability where relevant\n- Describe process interactions\n- Reference applicable procedures\n\nMANDATORY PROCESS:\nProcess Name: Quality Manual Development and Maintenance\nProcess Description:\nThis process ensures the Quality Manual accurately defines the QMS scope, structure, exclusions, and references to applicable procedures.\n\nREQUIRED DOCUMENTS:\n- Version-controlled Quality Manual\n\nREQUIRED RECORDS:\n- Version history\n- Approval records\n- Distribution records\n\nEXPECTED EVIDENCE:\n- Approved Quality Manual\n- Documented scope and exclusions\n- Controlled revision tracking\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.3_medical_device_file.txt'}, page_content='ISO 13485:2016\nClause: 4.2.3\nTitle: Medical Device File\n\nSUMMARY:\nClause 4.2.3 requires the organization to establish and maintain a medical device file for each type or family of medical device. The file must demonstrate conformity with ISO 13485 and regulatory requirements.\n\nREQUIREMENTS:\n- Establish a medical device file for each device type or family\n- Include device description and specifications\n- Include manufacturing and process information\n- Include verification and control documentation\n- Include installation and servicing information where applicable\n- Maintain the file up to date according to regulatory requirements\n\nMANDATORY PROCESS:\nProcess Name: Medical Device File Management\nProcess Description:\nThis process ensures the creation, maintenance, updating, and traceability of medical device files to demonstrate compliance and product conformity.\n\nREQUIRED DOCUMENTS:\n- Medical device file structure\n- Device specifications documentation\n- Manufacturing documentation\n\nREQUIRED RECORDS:\n- Device file update records\n- Product traceability records\n- Version control history\n\nEXPECTED EVIDENCE:\n- Complete and updated device files\n- Documented index and organization of files\n- Evidence of periodic updates\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.4_document_control.txt'}, page_content='ISO 13485:2016\nClause: 4.2.4\nTitle: Control of Documents\n\nSUMMARY:\nClause 4.2.4 requires the organization to establish and maintain a controlled document management system ensuring documents are reviewed, approved, updated, and distributed appropriately. Obsolete documents must be prevented from unintended use.\n\nREQUIREMENTS:\n- Implement a version control system\n- Ensure documents are reviewed and approved prior to release\n- Control document distribution\n- Prevent unintended use of obsolete documents\n- Manage externally originated documents\n\nMANDATORY PROCESS:\nProcess Name: Document Control Management\nProcess Description:\nThis process ensures QMS documents are identified, reviewed, approved, version-controlled, distributed appropriately, and protected against unintended use of obsolete versions.\n\nREQUIRED DOCUMENTS:\n- Document control procedure\n- External document control procedure (if separate)\n\nREQUIRED RECORDS:\n- Version history logs\n- Approval records\n- Distribution records\n- List of external documents\n\nEXPECTED EVIDENCE:\n- Documented version tracking\n- Approved document records\n- Controlled access to current versions\n- Identification of obsolete documents\n'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.5_record_control.txt'}, page_content='ISO 13485:2016\nClause: 4.2.5\nTitle: Control of Records\n\nSUMMARY:\nClause 4.2.5 requires the organization to control QMS records to ensure their identification, storage, protection, retrieval, retention, and controlled disposal.\n\nREQUIREMENTS:\n- Define retention periods for records\n- Define storage and archiving methods\n- Ensure integrity, confidentiality, and accessibility\n- Define controlled destruction procedures\n\nMANDATORY PROCESS:\nProcess Name: Record Control and Retention Management\nProcess Description:\nThis process ensures QMS records are properly identified, securely stored, retained for defined periods, protected against loss or alteration, and destroyed in a controlled manner when retention periods expire.\n\nREQUIRED DOCUMENTS:\n- Record control procedure\n- Retention policy\n\nREQUIRED RECORDS:\n- Retention register\n- Access logs\n- Archiving records\n- Destruction records\n\nEXPECTED EVIDENCE:\n- Defined retention schedule\n- Controlled record storage system\n- Evidence of secure destruction\n- Traceability of archived records\n')]

# %% [markdown]
# ### Document Splitting

# %%
# Initialize text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,  # Maximum size of each chunk
    chunk_overlap=150,  # Overlap between chunks to maintain context
    length_function=len,
    separators=[" "]  # Hierarchy of separators
)
chunks=text_splitter.split_documents(documents)

print(f"Created {len(chunks)} chunks from {len(documents)} documents")
print(f"\nChunk example:")
print(f"Content: {chunks[0].page_content[:150]}...")
print(f"Metadata: {chunks[0].metadata}")
# Out:
# Created 11 chunks from 11 documents
#
# Chunk example:
# Content: ISO 13485:2016
# Clause: 4.1.1
# Title: General Quality Management System Requirements
#
# SUMMARY:
# Clause 4.1.1 requires the organization to establish, docu...
# Metadata: {'source': '..\\data\\iso_13485\\4.1.1_general_qms_requirement.txt'}

# %%
for i,chunk in enumerate(chunks):
    print(f"metadata of chunk number {i+1} is {chunks[i].metadata}")
# Out:
# metadata of chunk number 1 is {'source': '..\\data\\iso_13485\\4.1.1_general_qms_requirement.txt'}
# metadata of chunk number 2 is {'source': '..\\data\\iso_13485\\4.1.2_process_approach_risk_based.txt'}
# metadata of chunk number 3 is {'source': '..\\data\\iso_13485\\4.1.3_process_monitoring_control.txt'}
# metadata of chunk number 4 is {'source': '..\\data\\iso_13485\\4.1.4_qms_change_management.txt'}
# metadata of chunk number 5 is {'source': '..\\data\\iso_13485\\4.1.5_outsourced_process_control.txt'}
# metadata of chunk number 6 is {'source': '..\\data\\iso_13485\\4.1.6_qms_software_validation.txt'}
# metadata of chunk number 7 is {'source': '..\\data\\iso_13485\\4.2.1_qms_documentation_requirements.txt'}
# metadata of chunk number 8 is {'source': '..\\data\\iso_13485\\4.2.2_quality_manual.txt'}
# metadata of chunk number 9 is {'source': '..\\data\\iso_13485\\4.2.3_medical_device_file.txt'}
# metadata of chunk number 10 is {'source': '..\\data\\iso_13485\\4.2.4_document_control.txt'}
# metadata of chunk number 11 is {'source': '..\\data\\iso_13485\\4.2.5_record_control.txt'}

# %% [markdown]
# ### Embeddings

# %%
sample_text="MAchine LEarning is fascinating"
embeddings=OpenAIEmbeddings()
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x00000173C740D6D0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x00000173C84C1190>, model='text-embedding-ada-002', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
vector=embeddings.embed_query(sample_text)
len(vector)
# Out:
# 1536

# %% [markdown]
# ### Initialized Vectore Store

# %%
chunks
# Out:
# [Document(metadata={'source': '..\\data\\iso_13485\\4.1.1_general_qms_requirement.txt'}, page_content='ISO 13485:2016\nClause: 4.1.1\nTitle: General Quality Management System Requirements\n\nSUMMARY:\nClause 4.1.1 requires the organization to establish, document, implement, and maintain a Quality Management System (QMS). The organization must define the QMS scope and clearly identify its regulatory role.\n\nREQUIREMENTS:\n- Define the scope and perimeter of the QMS\n- Identify and document the regulatory role of the organization (manufacturer, importer, distributor, etc.)\n- Establish and maintain a documented QMS compliant with ISO 13485 and applicable regulatory requirements\n\nMANDATORY PROCESS:\nProcess Name: QMS Governance and Scope Definition\nProcess Description:\nThis process ensures that the organization formally defines its QMS scope, regulatory responsibilities, and establishes a documented system aligned with ISO 13485 requirements.\n\nREQUIRED DOCUMENTS:\n- Quality Manual\n- Documented QMS scope description\n- Defined regulatory roles documentation\n- Quality Policy\n\nREQUIRED RECORDS:\n- Evidence of QMS implementation\n- Governance approval records\n\nEXPECTED EVIDENCE:\n- Approved Quality Manual\n- Defined organizational regulatory role\n- Implementation proof of QMS processes'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.2_process_approach_risk_based.txt'}, page_content='ISO 13485:2016\nClause: 4.1.2\nTitle: Process Approach and Risk-Based Approach\n\nSUMMARY:\nClause 4.1.2 requires the organization to apply a process-based approach within the QMS and integrate risk-based thinking into process control and management.\n\nREQUIREMENTS:\n- Identify all processes necessary for the QMS\n- Define the sequence and interaction between processes\n- Apply a risk-based approach to process control\n- Ensure risk management is integrated into process planning and execution\n\nMANDATORY PROCESS:\nProcess Name: Process Management and Risk Integration\nProcess Description:\nThis process ensures systematic identification, mapping, and risk evaluation of QMS processes, integrating risk-based thinking into process control and monitoring.\n\nREQUIRED DOCUMENTS:\n- Process mapping documentation\n- Process interaction diagram\n- Risk-based approach procedure\n\nREQUIRED RECORDS:\n- Process risk analyses\n- Process review records\n\nEXPECTED EVIDENCE:\n- Approved process map\n- Documented risk assessments per process\n- Evidence of risk-based decision making'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.3_process_monitoring_control.txt'}, page_content='ISO 13485:2016\nClause: 4.1.3\nTitle: Monitoring and Control of Processes\n\nSUMMARY:\nClause 4.1.3 requires the organization to define criteria and methods to ensure effective operation and control of QMS processes, including monitoring, measurement, and record retention.\n\nREQUIREMENTS:\n- Define operational criteria and control methods for processes\n- Establish performance indicators (KPIs) where appropriate\n- Monitor and measure processes\n- Maintain records demonstrating process control\n\nMANDATORY PROCESS:\nProcess Name: Process Monitoring and Performance Control\nProcess Description:\nThis process ensures the organization defines measurable criteria, monitors performance indicators, and maintains records demonstrating effective process control.\n\nREQUIRED DOCUMENTS:\n- Process procedures\n- Defined KPI framework\n- Monitoring and measurement procedures\n\nREQUIRED RECORDS:\n- Monitoring reports\n- KPI results\n- Process performance records\n\nEXPECTED EVIDENCE:\n- Documented monitoring results\n- KPI tracking logs\n- Records demonstrating process stability and control'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.4_qms_change_management.txt'}, page_content='ISO 13485:2016\nClause: 4.1.4\nTitle: Control of Changes to the QMS and Product\n\nSUMMARY:\nClause 4.1.4 requires the organization to control changes affecting the Quality Management System (QMS) or medical device conformity. All changes must be identified, evaluated, approved, and implemented in a controlled manner.\n\nREQUIREMENTS:\n- Identify proposed changes affecting the QMS\n- Evaluate the impact of changes on the QMS and on the medical device/product\n- Approve changes prior to implementation\n- Ensure controlled implementation of approved changes\n\nMANDATORY PROCESS:\nProcess Name: QMS Change Management and Control\nProcess Description:\nThis process ensures that any change affecting the QMS or product conformity is formally assessed, approved, documented, and implemented under controlled conditions.\n\nREQUIRED DOCUMENTS:\n- Change management procedure\n\nREQUIRED RECORDS:\n- Change register\n- Approved impact assessment records\n- Change approval documentation\n\nEXPECTED EVIDENCE:\n- Documented impact analyses\n- Approved change requests\n- Traceability of implemented changes'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.5_outsourced_process_control.txt'}, page_content='ISO 13485:2016\nClause: 4.1.5\nTitle: Control of Outsourced Processes\n\nSUMMARY:\nClause 4.1.5 requires the organization to control outsourced processes that impact product conformity. Monitoring and control mechanisms must be proportionate to the associated risk.\n\nREQUIREMENTS:\n- Identify outsourced processes impacting product conformity\n- Define monitoring and control measures proportionate to risk\n- Formalize quality requirements in written agreements with external providers\n\nMANDATORY PROCESS:\nProcess Name: Outsourced Process Control\nProcess Description:\nThis process ensures that externally provided processes are evaluated, monitored, and controlled to maintain product conformity and regulatory compliance.\n\nREQUIRED DOCUMENTS:\n- Outsourcing control procedure\n- Supplier quality agreements\n- Contractual quality requirements\n\nREQUIRED RECORDS:\n- Supplier evaluations\n- Supplier audit reports\n- Monitoring and performance records\n\nEXPECTED EVIDENCE:\n- Approved supplier agreements\n- Documented supplier evaluations\n- Audit findings and follow-up actions'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.1.6_qms_software_validation.txt'}, page_content='ISO 13485:2016\nClause: 4.1.6\nTitle: Validation of Software Used in the QMS\n\nSUMMARY:\nClause 4.1.6 requires the organization to validate software used within the QMS prior to initial use and after modifications when necessary. Risks associated with software use must be assessed.\n\nREQUIREMENTS:\n- Identify all software used in QMS processes\n- Assess risks associated with software usage\n- Validate software before initial use\n- Revalidate software after changes when required\n\nMANDATORY PROCESS:\nProcess Name: QMS Software Validation\nProcess Description:\nThis process ensures that software tools used in QMS activities are risk-assessed, validated, and maintained in a validated state to ensure reliability and compliance.\n\nREQUIRED DOCUMENTS:\n- Software validation procedure\n- QMS software register\n\nREQUIRED RECORDS:\n- Software validation reports\n- Revalidation records\n- Validation logs\n\nEXPECTED EVIDENCE:\n- Documented validation protocols\n- Approved validation results\n- Risk assessment documentation for software tools'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.1_qms_documentation_requirements.txt'}, page_content='ISO 13485:2016\nClause: 4.2.1\nTitle: General Documentation Requirements\n\nSUMMARY:\nClause 4.2.1 requires the organization to establish and maintain documented information required by ISO 13485. The documentation architecture of the QMS must be structured and controlled.\n\nREQUIREMENTS:\n- Identify all documents and records required by ISO 13485\n- Structure the QMS documentation architecture\n- Maintain a master list of controlled documents\n- Ensure documents remain current and accessible\n\nMANDATORY PROCESS:\nProcess Name: QMS Documentation Architecture Management\nProcess Description:\nThis process ensures identification, structuring, control, and maintenance of all QMS documentation in accordance with ISO 13485 requirements.\n\nREQUIRED DOCUMENTS:\n- Documentation architecture description\n- Master list of controlled documents\n- Document control procedure\n\nREQUIRED RECORDS:\n- Document history records\n- Evidence of document control activities\n\nEXPECTED EVIDENCE:\n- Approved documentation structure\n- Updated master document list\n- Controlled access and version management records'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.2_quality_manual.txt'}, page_content='ISO 13485:2016\nClause: 4.2.2\nTitle: Quality Manual\n\nSUMMARY:\nClause 4.2.2 requires the organization to establish and maintain a Quality Manual defining the scope of the QMS and describing process interactions.\n\nREQUIREMENTS:\n- Establish a documented Quality Manual\n- Define the QMS scope within the manual\n- Justify exclusions or non-applicability where relevant\n- Describe process interactions\n- Reference applicable procedures\n\nMANDATORY PROCESS:\nProcess Name: Quality Manual Development and Maintenance\nProcess Description:\nThis process ensures the Quality Manual accurately defines the QMS scope, structure, exclusions, and references to applicable procedures.\n\nREQUIRED DOCUMENTS:\n- Version-controlled Quality Manual\n\nREQUIRED RECORDS:\n- Version history\n- Approval records\n- Distribution records\n\nEXPECTED EVIDENCE:\n- Approved Quality Manual\n- Documented scope and exclusions\n- Controlled revision tracking'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.3_medical_device_file.txt'}, page_content='ISO 13485:2016\nClause: 4.2.3\nTitle: Medical Device File\n\nSUMMARY:\nClause 4.2.3 requires the organization to establish and maintain a medical device file for each type or family of medical device. The file must demonstrate conformity with ISO 13485 and regulatory requirements.\n\nREQUIREMENTS:\n- Establish a medical device file for each device type or family\n- Include device description and specifications\n- Include manufacturing and process information\n- Include verification and control documentation\n- Include installation and servicing information where applicable\n- Maintain the file up to date according to regulatory requirements\n\nMANDATORY PROCESS:\nProcess Name: Medical Device File Management\nProcess Description:\nThis process ensures the creation, maintenance, updating, and traceability of medical device files to demonstrate compliance and product conformity.\n\nREQUIRED DOCUMENTS:\n- Medical device file structure\n- Device specifications documentation\n- Manufacturing documentation\n\nREQUIRED RECORDS:\n- Device file update records\n- Product traceability records\n- Version control history\n\nEXPECTED EVIDENCE:\n- Complete and updated device files\n- Documented index and organization of files\n- Evidence of periodic updates'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.4_document_control.txt'}, page_content='ISO 13485:2016\nClause: 4.2.4\nTitle: Control of Documents\n\nSUMMARY:\nClause 4.2.4 requires the organization to establish and maintain a controlled document management system ensuring documents are reviewed, approved, updated, and distributed appropriately. Obsolete documents must be prevented from unintended use.\n\nREQUIREMENTS:\n- Implement a version control system\n- Ensure documents are reviewed and approved prior to release\n- Control document distribution\n- Prevent unintended use of obsolete documents\n- Manage externally originated documents\n\nMANDATORY PROCESS:\nProcess Name: Document Control Management\nProcess Description:\nThis process ensures QMS documents are identified, reviewed, approved, version-controlled, distributed appropriately, and protected against unintended use of obsolete versions.\n\nREQUIRED DOCUMENTS:\n- Document control procedure\n- External document control procedure (if separate)\n\nREQUIRED RECORDS:\n- Version history logs\n- Approval records\n- Distribution records\n- List of external documents\n\nEXPECTED EVIDENCE:\n- Documented version tracking\n- Approved document records\n- Controlled access to current versions\n- Identification of obsolete documents'),
#  Document(metadata={'source': '..\\data\\iso_13485\\4.2.5_record_control.txt'}, page_content='ISO 13485:2016\nClause: 4.2.5\nTitle: Control of Records\n\nSUMMARY:\nClause 4.2.5 requires the organization to control QMS records to ensure their identification, storage, protection, retrieval, retention, and controlled disposal.\n\nREQUIREMENTS:\n- Define retention periods for records\n- Define storage and archiving methods\n- Ensure integrity, confidentiality, and accessibility\n- Define controlled destruction procedures\n\nMANDATORY PROCESS:\nProcess Name: Record Control and Retention Management\nProcess Description:\nThis process ensures QMS records are properly identified, securely stored, retained for defined periods, protected against loss or alteration, and destroyed in a controlled manner when retention periods expire.\n\nREQUIRED DOCUMENTS:\n- Record control procedure\n- Retention policy\n\nREQUIRED RECORDS:\n- Retention register\n- Access logs\n- Archiving records\n- Destruction records\n\nEXPECTED EVIDENCE:\n- Defined retention schedule\n- Controlled record storage system\n- Evidence of secure destruction\n- Traceability of archived records')]

# %%
## Create a Chromdb vector store
persist_directory=".././outpot_db"

## Initialize Chromadb with Open AI embeddings
vectorstore=Chroma.from_documents(
    documents=chunks,
    embedding=OpenAIEmbeddings(),
    persist_directory=persist_directory,
    collection_name="rag_collection"

)

print(f"Vector store created with {vectorstore._collection.count()} vectors")
print(f"Persisted to: {persist_directory}")
# Out:
# Vector store created with 11 vectors
# Persisted to: .././outpot_db

# %%
query="what is requirements of General Quality Management System Requirements?"

similar_docs=vectorstore.similarity_search(query,k=3)
similar_docs[1].page_content
# Out:
# 'ISO 13485:2016\nClause: 4.2.1\nTitle: General Documentation Requirements\n\nSUMMARY:\nClause 4.2.1 requires the organization to establish and maintain documented information required by ISO 13485. The documentation architecture of the QMS must be structured and controlled.\n\nREQUIREMENTS:\n- Identify all documents and records required by ISO 13485\n- Structure the QMS documentation architecture\n- Maintain a master list of controlled documents\n- Ensure documents remain current and accessible\n\nMANDATORY PROCESS:\nProcess Name: QMS Documentation Architecture Management\nProcess Description:\nThis process ensures identification, structuring, control, and maintenance of all QMS documentation in accordance with ISO 13485 requirements.\n\nREQUIRED DOCUMENTS:\n- Documentation architecture description\n- Master list of controlled documents\n- Document control procedure\n\nREQUIRED RECORDS:\n- Document history records\n- Evidence of document control activities\n\nEXPECTED EVIDENCE:\n- Approved documentation structure\n- Updated master document list\n- Controlled access and version management records'

# %%
for i , content in enumerate(similar_docs):
    print("----------------------------------------------------------------------")
    print(f"content of similar docs : {similar_docs[i].page_content}")
    print("-----------------------------------------------------------------------")
    print(f"metdata of similar docs {similar_docs[i].metadata}")
    print("-----------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------
# content of similar docs : ISO 13485:2016
# Clause: 4.1.1
# Title: General Quality Management System Requirements
#
# SUMMARY:
# Clause 4.1.1 requires the organization to establish, document, implement, and maintain a Quality Management System (QMS). The organization must define the QMS scope and clearly identify its regulatory role.
#
# REQUIREMENTS:
# - Define the scope and perimeter of the QMS
# - Identify and document the regulatory role of the organization (manufacturer, importer, distributor, etc.)
# - Establish and maintain a documented QMS compliant with ISO 13485 and applicable regulatory requirements
#
# MANDATORY PROCESS:
# Process Name: QMS Governance and Scope Definition
# Process Description:
# This process ensures that the organization formally defines its QMS scope, regulatory responsibilities, and establishes a documented system aligned with ISO 13485 requirements.
#
# REQUIRED DOCUMENTS:
# - Quality Manual
# - Documented QMS scope description
# - Defined regulatory roles documentation
# - Quality Policy
#
# REQUIRED RECORDS:
# - Evidence of QMS implementation
# - Governance approval records
#
# EXPECTED EVIDENCE:
# - Approved Quality Manual
# - Defined organizational regulatory role
# - Implementation proof of QMS processes
# -----------------------------------------------------------------------
# metdata of similar docs {'source': '..\\data\\iso_13485\\4.1.1_general_qms_requirement.txt'}
# -----------------------------------------------------------------------
# ----------------------------------------------------------------------
# content of similar docs : ISO 13485:2016
# Clause: 4.2.1
# Title: General Documentation Requirements
#
# SUMMARY:
# Clause 4.2.1 requires the organization to establish and maintain documented information required by ISO 13485. The documentation architecture of the QMS must be structured and controlled.
#
# REQUIREMENTS:
# - Identify all documents and records required by ISO 13485
# - Structure the QMS documentation architecture
# - Maintain a master list of controlled documents
# - Ensure documents remain current and accessible
#
# MANDATORY PROCESS:
# Process Name: QMS Documentation Architecture Management
# Process Description:
# This process ensures identification, structuring, control, and maintenance of all QMS documentation in accordance with ISO 13485 requirements.
#
# REQUIRED DOCUMENTS:
# - Documentation architecture description
# - Master list of controlled documents
# - Document control procedure
#
# REQUIRED RECORDS:
# - Document history records
# - Evidence of document control activities
#
# EXPECTED EVIDENCE:
# - Approved documentation structure
# - Updated master document list
# - Controlled access and version management records
# -----------------------------------------------------------------------
# metdata of similar docs {'source': '..\\data\\iso_13485\\4.2.1_qms_documentation_requirements.txt'}
# -----------------------------------------------------------------------
# ----------------------------------------------------------------------
# content of similar docs : ISO 13485:2016
# Clause: 4.2.2
# Title: Quality Manual
#
# SUMMARY:
# Clause 4.2.2 requires the organization to establish and maintain a Quality Manual defining the scope of the QMS and describing process interactions.
#
# REQUIREMENTS:
# - Establish a documented Quality Manual
# - Define the QMS scope within the manual
# - Justify exclusions or non-applicability where relevant
# - Describe process interactions
# - Reference applicable procedures
#
# MANDATORY PROCESS:
# Process Name: Quality Manual Development and Maintenance
# Process Description:
# This process ensures the Quality Manual accurately defines the QMS scope, structure, exclusions, and references to applicable procedures.
#
# REQUIRED DOCUMENTS:
# - Version-controlled Quality Manual
#
# REQUIRED RECORDS:
# - Version history
# - Approval records
# - Distribution records
#
# EXPECTED EVIDENCE:
# - Approved Quality Manual
# - Documented scope and exclusions
# - Controlled revision tracking
# -----------------------------------------------------------------------
# metdata of similar docs {'source': '..\\data\\iso_13485\\4.2.2_quality_manual.txt'}
# -----------------------------------------------------------------------

# %% [markdown]
# #### Initialize LLM, RAG Chain, Prompt Template,Query the RAG system

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(
    model_name="gpt-3.5-turbo"
)

# %%
test_response=llm.invoke("What is Large Language Models")
test_response
# Out:
# AIMessage(content='Large Language Models are a type of artificial intelligence model that are designed to process and understand vast amounts of text data. These models use advanced natural language processing and machine learning techniques to generate human-like text and respond to queries in a way that is coherent and contextually relevant. Large Language Models have been used for a variety of applications, including language translation, text completion, question answering, and chatbots. Some well-known examples of Large Language Models include GPT-3, BERT, and Transformer.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 12, 'total_tokens': 112, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DAaK5BB8EMH454uTdM8yKMXQohxng', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--019c7094-06cc-7c83-844a-01a50973f6fa-0', usage_metadata={'input_tokens': 12, 'output_tokens': 100, 'total_tokens': 112, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain.chat_models.base import init_chat_model

llm=init_chat_model("openai:gpt-3.5-turbo")
#llm=init_chat_model("groq:")
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000173CCCB22B0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000173CCCB2220>, root_client=<openai.OpenAI object at 0x00000173CCCB2670>, root_async_client=<openai.AsyncOpenAI object at 0x00000173CCCB24F0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %% [markdown]
# ### Modern RAG Chain

# %%
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain

# %%
## Convert vector store to retriever
retriever=vectorstore.as_retriever(
    search_kwarg={"k":3} ## Retrieve top 3 relevant chunks
)
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x00000173C859CFD0>, search_kwargs={})

# %%
from langchain_core.prompts import ChatPromptTemplate

system_prompt = """
You are a regulatory compliance assistant specialized in ISO 13485:2016 and Quality Management Systems (QMS).

You must answer strictly based on the retrieved context provided below.

Rules:
- Use ONLY the information found in the context.
- Do NOT add external knowledge.
- Do NOT assume missing information.
- If the answer is not explicitly available in the context, say:
  "The requested information is not available in the provided ISO 13485 context."
- Clearly reference the relevant ISO 13485 clause number in your answer.
- Use professional regulatory language.
- Organize the answer in numbered points (1-, 2-, 3-, etc.).
- When appropriate, group information under clear headings (e.g., Summary, Requirements, Required Documents, Required Records).
- Keep the explanation precise and structured.

Retrieved Context:
{context}
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "Question: {input}")
])

# %% [markdown]
# ##### What is create_stuff_documents_chain?
# create_stuff_documents_chain creates a chain that "stuffs" (inserts) all retrieved documents into a single prompt and sends it to the LLM. It's called "stuff" because it literally stuffs all the documents into the context window at once.

# %%
### Create a document chain
from langchain.chains.combine_documents import create_stuff_documents_chain
document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nYou are a regulatory compliance assistant specialized in ISO 13485:2016 and Quality Management Systems (QMS).\n\nYou must answer strictly based on the retrieved context provided below.\n\nRules:\n- Use ONLY the information found in the context.\n- Do NOT add external knowledge.\n- Do NOT assume missing information.\n- If the answer is not explicitly available in the context, say:\n  "The requested information is not available in the provided ISO 13485 context."\n- Clearly reference the relevant ISO 13485 clause number in your answer.\n- Use professional regulatory language.\n- Organize the answer in numbered points (1-, 2-, 3-, etc.).\n- When appropriate, group information under clear headings (e.g., Summary, Requirements, Required Documents, Required Records).\n- Keep the explanation precise and structured.\n\nRetrieved Context:\n{context}\n'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='Question: {input}'), additional_kwargs={})])
# | ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000173CCCB22B0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000173CCCB2220>, root_client=<openai.OpenAI object at 0x00000173CCCB2670>, root_async_client=<openai.AsyncOpenAI object at 0x00000173CCCB24F0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)
# | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])

# %% [markdown]
# #### What is create_retrieval_chain?
# create_retrieval_chain is a function that combines a retriever (which fetches relevant documents) with a document chain (which processes those documents with an LLM) to create a complete RAG pipeline.

# %%
### Create The Final RAG Chain
from langchain.chains import create_retrieval_chain
rag_chain=create_retrieval_chain(retriever,document_chain)
rag_chain
# Out:
# RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableBinding(bound=RunnableLambda(lambda x: x['input'])
#            | VectorStoreRetriever(tags=['Chroma', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x00000173C859CFD0>, search_kwargs={}), kwargs={}, config={'run_name': 'retrieve_documents'}, config_factories=[])
# })
# | RunnableAssign(mapper={
#     answer: RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#               context: RunnableLambda(format_docs)
#             }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
#             | ChatPromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nYou are a regulatory compliance assistant specialized in ISO 13485:2016 and Quality Management Systems (QMS).\n\nYou must answer strictly based on the retrieved context provided below.\n\nRules:\n- Use ONLY the information found in the context.\n- Do NOT add external knowledge.\n- Do NOT assume missing information.\n- If the answer is not explicitly available in the context, say:\n  "The requested information is not available in the provided ISO 13485 context."\n- Clearly reference the relevant ISO 13485 clause number in your answer.\n- Use professional regulatory language.\n- Organize the answer in numbered points (1-, 2-, 3-, etc.).\n- When appropriate, group information under clear headings (e.g., Summary, Requirements, Required Documents, Required Records).\n- Keep the explanation precise and structured.\n\nRetrieved Context:\n{context}\n'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='Question: {input}'), additional_kwargs={})])
#             | ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000173CCCB22B0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000173CCCB2220>, root_client=<openai.OpenAI object at 0x00000173CCCB2670>, root_async_client=<openai.AsyncOpenAI object at 0x00000173CCCB24F0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)
#             | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])
#   }), kwargs={}, config={'run_name': 'retrieval_chain'}, config_factories=[])

# %%
response=rag_chain.invoke({"input":"what is requirements of General Quality Management System Requirements?"})

# %%
response['answer']
# Out:
# 'The requirements of General Quality Management System Requirements under Clause 4.1.1 of ISO 13485:2016 include:\n\n1- **Define the QMS Scope and Perimeter**:\n   - The organization must clearly define the scope and boundaries of its Quality Management System (QMS).\n\n2- **Identify and Document Regulatory Role**:\n   - The organization must identify and document its regulatory role within the QMS, such as being a manufacturer, importer, distributor, etc.\n\n3- **Establish and Maintain a Documented QMS**:\n   - The organization is required to establish and maintain a documented QMS in compliance with ISO 13485 requirements and applicable regulatory requirements.'

# %%
# Function to query the modern RAG system
def query_rag_modern(question):
    print(f"Question: {question}")
    print("-" * 50)
    
    # Using create_retrieval_chain approach
    result = rag_chain.invoke({"input": question})
    
    print(f"{result['answer']}")
    # print("\nRetrieved Context:")
    # for i, doc in enumerate(result['context']):
    #     # print(f"\n--- Source {i+1} ---")
    #     print(doc.page_content)
    
    return result

# Test queries
test_questions = [
    "what is REQUIRED RECORDS of Quality Manual"
]

for question in test_questions:
    result = query_rag_modern(question)
    print("\n" + "="*80 + "\n")
# Out:
# Question: what is REQUIRED RECORDS of Quality Manual
# --------------------------------------------------
# Based on the information provided in ISO 13485:2016, Clause 4.2.2 regarding the Quality Manual, the REQUIRED RECORDS related to the Quality Manual are as follows:
#
# 1- Retention records:
#    - These records should include the version history, approval records, and distribution records of the Quality Manual.
#    - The retention records should demonstrate the traceability and control of changes made to the Quality Manual over time.
#    - These records are essential for maintaining a documented history of the Quality Manual, ensuring that approved versions are available for reference, and identifying who approved and received specific versions of the Quality Manual.
#
# ================================================================================
